# %%
import numpy as np
import random
import math
import copy
import pandas as pd
import time
import json
import matplotlib.pyplot as plt

# %%
# === Load dataset ===

# Load only the CUSTOMER section of the text file
data = pd.read_fwf("rc104.txt", skiprows=8, header=None)
data.columns = ["CUST_NO", "XCOORD", "YCOORD", "DEMAND", "READY_TIME", "DUE_DATE", "SERVICE_TIME"]


# Load data from previous period
data_pre = pd.read_fwf("rc103.txt", skiprows=8, header=None)
data_pre.columns = ["CUST_NO", "XCOORD", "YCOORD", "DEMAND", "READY_TIME", "DUE_DATE", "SERVICE_TIME"]

# %%
# === Sets ===
V = list(range(25))  # 25 vehicles
C = list(range(1, len(data)))  # Customers (1 to n), excluding depot (0)
N = list(range(len(data)))  # All nodes including depot
# === Parameters ===
dc = data['DEMAND'].tolist()
dc[0] = 0  # Depot demand = 0
dc_pre = data_pre['DEMAND'].tolist()
dc_pre[0] = 0  # Depot demand = 0
coords = list(zip(data['XCOORD'], data['YCOORD']))
ai = data['READY_TIME'].tolist()
bi = data['DUE_DATE'].tolist()
si = data['SERVICE_TIME'].tolist()

# %%
# Problem parameters
cij = 30
delta = 0.17        #https://progresschamber.org/wp-content/uploads/2024/06/Chamber-of-Progress-Efficiency-and-Emissions-Impact-of-Last-Mile-Online-Delivery-in-the-US.pdf
lambda_v = 200
pi = 10
theta = 0.7
mv = 100000
cv = 100
hv = 15
ev = 0.1
cf = 0.5                                                                                        
fv = 0.1
gamma = 0.1
M = 1000000
w1, w2, w3 = 1, 1, 1  # weight for objectives
alpha_w, beta_w, gamma_w = 1, 1, 1  # penalty weights

dc_rev = [round(d * delta) for d in dc_pre]  # Integer reverse demand!!!!

# %%
# === Distance matrix ===
t = np.zeros((len(N), len(N)))
for i in N:
    for j in N:
        t[i][j] = math.hypot(coords[i][0] - coords[j][0], coords[i][1] - coords[j][1])

# %%
# === Initialize weights and scores ===
destruction_weights = [1.0] * 5
repair_weights = [1.0] * 5
destruction_scores = [0] * 5
repair_scores = [0] * 5
destruction_usage = [1] * 5
repair_usage = [1] * 5
alpha = 0.4  # weight update parameter

# %%
# === Roulette Wheel Selection ===
def select_operator(weights):
    total = sum(weights)
    r = random.uniform(0, total)
    cumulative = 0
    for i, w in enumerate(weights):
        cumulative += w
        if r <= cumulative:
            return i
    return len(weights) - 1  # fallback

# %%
# === Update Weights ===
def update_weights(weights, scores, usage):
    for i in range(len(weights)):
        weights[i] = alpha * weights[i] + (1 - alpha) * (scores[i] / usage[i] if usage[i] else 0)
        scores[i] = 0
        usage[i] = 1

# %%
# === Destruction Operators ===

# 1. Random Destroy Operator
def random_destroy(routes, fraction=0.4):
    all_customers = [(v, cust) for v in range(len(routes)) for cust in routes[v] if cust != 0]
    num_remove = max(1, int(len(all_customers) * fraction))
    to_remove = random.sample(all_customers, num_remove)
    removed = []
    for v, cust in to_remove:
        if cust in routes[v]:
            routes[v].remove(cust)
            removed.append(cust)
    return removed, routes

# 2. Similarity Destroy Operator
def similarity_destroy(routes, coords, q=5):
    # Normalize distances
    max_dist = max(math.dist(a, b) for a in coords for b in coords if a != b)

    def similarity(i, j):
        dist = math.dist(coords[i], coords[j]) / max_dist  # normalized c_ij
        same_route = any(i in r and j in r for r in routes)
        Vij = 0 if same_route else 1
        return 1 / (dist + Vij)

    all_customers = [cust for r in routes for cust in r if cust != 0]
    seed = random.choice(all_customers)
    removed = [seed]

    while len(removed) < q:
        curr = random.choice(removed)
        candidates = [c for c in all_customers if c not in removed]
        if not candidates:
            break

        candidates.sort(key=lambda j: -similarity(curr, j))
        rand_index = int(random.random() * len(candidates))
        selected = candidates[rand_index]
        removed.append(selected)

    for v in range(len(routes)):
        routes[v] = [c for c in routes[v] if c not in removed]

    return removed, routes


# 3. Maximum Saving Cost Destroy Operator
def max_saving_destroy(routes, coords, q=5):
    savings = []
    for v, route in enumerate(routes):
        for i in range(1, len(route) - 1):
            prev, curr, next_ = route[i-1], route[i], route[i+1]
            saving = t[prev][curr] + t[curr][next_] - t[prev][next_]
            savings.append((saving, v, curr))
    savings.sort(reverse=True)
    removed = [cust for _, v, cust in savings[:q]]
    for _, v, cust in savings[:q]:
        routes[v].remove(cust)
    return removed, routes

# 4. Destroying Vehicle Destroy Operator
def destroying_vehicle_destroy(routes):
    max_cost = -1
    vehicle_to_remove = -1

    for v, route in enumerate(routes):
        if not route or len(route) < 2:
            continue

        # Path length
        path_length = sum(t[route[i]][route[i+1]] for i in range(len(route) - 1))

        # Average waiting time
        time = 0
        wait_total = 0
        visits = 0

        for i in range(1, len(route)):
            prev = route[i - 1]
            curr = route[i]
            travel = t[prev][curr]
            time += travel

            if curr != 0:  # Ignore depot
                wait = max(0, ai[curr] - time)
                wait_total += wait
                time += si[curr]
                visits += 1

        avg_wait = wait_total / visits if visits > 0 else 0

        # Weighted cost metric
        cost = 0.7 * path_length + 0.3 * avg_wait

        if cost > max_cost:
            max_cost = cost
            vehicle_to_remove = v

    # Remove all customers from that vehicle's route
    removed = [cust for cust in routes[vehicle_to_remove] if cust != 0]
    routes[vehicle_to_remove] = []

    return removed, routes


# 5. Maximum Waiting Time Destroy Operator 
def max_waiting_time_destroy(routes, ai, bi, si):
    def calc_wait(route):
        time = 0
        wait_total = 0
        for i in range(1, len(route)):
            prev = route[i - 1]
            curr = route[i]
            travel = t[prev][curr]
            time += travel

            # Actual waiting if early
            if curr != 0:
                wait = max(0, ai[curr] - time)

                # Penalty if late
                late_penalty = max(0, time - bi[curr]) * 10

                wait_total += wait + late_penalty

                time += si[curr]
        return wait_total

    vehicle_to_remove = max(range(len(routes)), key=lambda v: calc_wait(routes[v]))
    removed = [cust for cust in routes[vehicle_to_remove] if cust != 0]
    routes[vehicle_to_remove] = []
    return removed, routes


destruction_ops = [
    lambda r: random_destroy(r, fraction=0.4),
    lambda r: similarity_destroy(r, coords, q=5),
    lambda r: max_saving_destroy(r, coords, q=5),
    lambda r: max_waiting_time_destroy(r, ai, bi, si),
    lambda r: destroying_vehicle_destroy(r)
]

# %%
# === Repair Operators ===

# Delta cost evaluation function
def delta_insertion_cost(route, i, cust):
    prev = route[i - 1]
    next_ = route[i] if i < len(route) else 0
    delta = t[prev][cust] + t[cust][next_] - t[prev][next_]
    return delta

# 1. Global Optimal Repair Operator
def global_optimal_repair(routes, removed):
    for cust in removed:
        best_cost = float('inf')
        best_pos = None
        for v, route in enumerate(routes):
            for i in range(1, len(route)):
                if not is_time_window_feasible(route, i, cust, ai, bi, si, t):
                    continue
                if not is_capacity_feasible(route, i, cust, dc, dc_rev, lambda_v):
                    continue
                delta = delta_insertion_cost(route, i, cust)
                if delta < best_cost:
                    best_cost = delta
                    best_pos = (v, i)
        if best_pos:
            v, i = best_pos
            routes[v].insert(i, cust)
        else:
            # Start a new route if no feasible position found
            routes.append([0, cust, 0])
    return routes

# 2. Minimum Insertion Cost Repair Operator
def min_insertion_cost_repair(routes, removed):
    pending = removed[:]
    while pending:
        best_costs = []

        for cust in pending:
            best_delta = float("inf")
            best_wait = float("inf")
            best_pos = None

            for v, route in enumerate(routes):
                for i in range(1, len(route)):
                    if not is_time_window_feasible(route, i, cust, ai, bi, si, t):
                        continue
                    if not is_capacity_feasible(route, i, cust, dc, dc_rev, lambda_v):
                        continue

                    # Delta cost (local evaluation)
                    prev, next_ = route[i - 1], route[i]
                    delta_cost = t[prev][cust] + t[cust][next_] - t[prev][next_]

                    # Estimate waiting time after insertion
                    arrival = 0
                    for j in range(1, i):
                        arrival += t[route[j - 1]][route[j]] + si[route[j - 1]]
                    arrival += t[route[i - 1]][cust]
                    wait_time = max(0, ai[cust] - arrival)

                    if (delta_cost < best_delta) or (delta_cost == best_delta and wait_time < best_wait):
                        best_delta = delta_cost
                        best_wait = wait_time
                        best_pos = (v, i)

            best_costs.append((best_delta, cust, best_pos))

        # Choose customer with largest minimum insertion cost
        best_costs.sort(reverse=True)
        _, selected_cust, selected_pos = best_costs[0]

        if selected_pos:
            v, i = selected_pos
            routes[v].insert(i, selected_cust)
        else:
            # No feasible insertion thencreate a new route
            routes.append([0, selected_cust, 0])

        pending.remove(selected_cust)

    return routes

# 3. Random K Repair Operator
def random_k_repair(routes, removed, ai, bi, si, t, dc, dc_rev, lambda_v, current_iter):
    
    k_dynamic = 5 + current_iter // 500

    for cust in removed:
        candidates = []

        for v, route in enumerate(routes):
            for i in range(1, len(route)):  # Skip depot at 0
                if not is_time_window_feasible(route, i, cust, ai, bi, si, t):
                    continue
                if not is_capacity_feasible(route, i, cust, dc, dc_rev, lambda_v):
                    continue

                prev, next_ = route[i - 1], route[i]
                delta_cost = t[prev][cust] + t[cust][next_] - t[prev][next_]

                candidates.append((delta_cost, v, i))

        if candidates:
            candidates.sort()
            chosen = random.choice(candidates[:min(k_dynamic, len(candidates))])
            _, v, i = chosen
            routes[v].insert(i, cust)
        else:
            routes.append([0, cust, 0])  # New route if no insertion possible

    return routes


# 4. Regret Criterion Repair Operator
def regret_repair(routes, removed, ai, bi, si, t, dc, dc_rev, lambda_v, k=5):

    while removed:
        regrets = []

        for cust in removed:
            candidate_positions = []

            for v, route in enumerate(routes):
                for i in range(1, len(route)):
                    if not is_time_window_feasible(route, i, cust, ai, bi, si, t):
                        continue
                    if not is_capacity_feasible(route, i, cust, dc, dc_rev, lambda_v):
                        continue
                    prev, next_ = route[i - 1], route[i]
                    delta = t[prev][cust] + t[cust][next_] - t[prev][next_]
                    candidate_positions.append((delta, v, i))

            if len(candidate_positions) >= k:
                candidate_positions.sort()
                regret = sum(candidate_positions[j][0] - candidate_positions[0][0] for j in range(1, k))
                regrets.append((regret, cust, candidate_positions[0]))

        if regrets:
            regrets.sort(reverse=True)  # Max regret first
            _, chosen_cust, (best_delta, v, i) = regrets[0]
            routes[v].insert(i, chosen_cust)
            removed.remove(chosen_cust)
        else:
            # No feasible insertion for any customer, create new route for one
            chosen_cust = removed.pop(0)
            routes.append([0, chosen_cust, 0])

    return routes


# 5. Minimum Waiting Time Repair Operator
def min_waiting_time_repair(routes, removed, ai, bi, si, t, dc, dc_rev, lambda_v):
    for cust in removed:
        best_pos = None
        min_wait = float('inf')

        for v, route in enumerate(routes):
            time = 0  # cumulative time along the route

            for i in range(1, len(route)):
                prev = route[i - 1]
                departure_prev = time + si[prev]
                travel = t[prev][cust]
                arrival = max(departure_prev + travel, ai[cust])
                wait = arrival - departure_prev - travel

                if not is_time_window_feasible(route, i, cust, ai, bi, si, t):
                    continue
                if not is_capacity_feasible(route, i, cust, dc, dc_rev, lambda_v):
                    continue

                if wait < min_wait:
                    min_wait = wait
                    best_pos = (v, i)

                # update time to next node
                next_node = route[i]
                time = departure_prev + t[prev][next_node]

        if best_pos:
            v, i = best_pos
            routes[v].insert(i, cust)
        else:
            routes.append([0, cust, 0])  # New route for isolated customer

    return routes


repair_ops = [
    lambda r, rem: global_optimal_repair(r, rem),
    lambda r, rem: min_insertion_cost_repair(r, rem),
    lambda r, rem: regret_repair(r, rem, ai, bi, si, t, dc, dc_rev, lambda_v, k=5),
    None,
    lambda r, rem: min_waiting_time_repair(r, rem, ai, bi, si, t, dc, dc_rev, lambda_v)
]

# %%
# === 1. Nearest Neighbor Heuristic ===
def nearest_neighbor_initial_solution():
    unvisited = set(C)
    routes = [[] for _ in V]
    v = 0

    while unvisited:
        if v >= len(V):
            raise RuntimeError("Insufficient vehicles.")
        route = [0]
        load = 0
        curr = 0
        while True:
            nearest = None
            nearest_dist = float('inf')
            for cust in unvisited:
                if dc[cust] + load <= lambda_v and t[curr][cust] < nearest_dist:
                    nearest = cust
                    nearest_dist = t[curr][cust]
            if nearest is None:
                break
            route.append(nearest)
            load += dc[nearest]
            curr = nearest
            unvisited.remove(nearest)
        route.append(0)
        routes[v] = route
        v += 1
    return routes
initial_routes = nearest_neighbor_initial_solution()

import json
with open("routes_nns.json", "w") as f:
    json.dump(initial_routes, f)

    # Preview output
for v, route in enumerate(initial_routes):
    if route:
        print(f"Vehicle {v}: {route}")
# Out:
# Vehicle 0: [0, 90, 65, 66, 83, 64, 56, 95, 92, 91, 80, 94, 93, 71, 96, 0]
# Vehicle 1: [0, 69, 98, 53, 88, 55, 100, 70, 68, 61, 81, 54, 72, 41, 39, 62, 0]
# Vehicle 2: [0, 82, 99, 52, 57, 86, 74, 87, 59, 97, 75, 58, 77, 85, 0]
# Vehicle 3: [0, 67, 50, 34, 31, 29, 27, 26, 28, 30, 32, 33, 63, 73, 0]
# Vehicle 4: [0, 60, 78, 12, 14, 47, 17, 16, 15, 13, 9, 24, 20, 0]
# Vehicle 5: [0, 84, 51, 76, 89, 18, 48, 21, 23, 25, 49, 0]
# Vehicle 6: [0, 2, 6, 7, 8, 46, 4, 45, 5, 3, 1, 44, 0]
# Vehicle 7: [0, 10, 11, 79, 42, 43, 40, 36, 0]
# Vehicle 8: [0, 22, 19, 38, 37, 35, 0]

# %%
# === a Feasibility Checker Function ===

# Helper function for capacity check
def is_capacity_feasible(route, insert_pos, cust, dc, dc_rev, lambda_v):
    # Create a tentative new route with cust inserted at the position
    new_route = route[:insert_pos] + [cust] + route[insert_pos:]

    load = 0  # initial load is 0
    for node in new_route:
        if node == 0:
            continue  # depot, skip
        # Deliver forward items
        deliver = dc[node]
        if load >= deliver:
            load -= deliver
        else:
            deliver = load  # deliver what we can
            load = 0
        # Pick up reverse items (adds to load)
        pickup = dc_rev[node]
        load += pickup
        # Check capacity after pickup
        if load > lambda_v:
            return False
    return True


def is_time_window_feasible(route, insert_pos, cust, ai, bi, si, t):
    prev = route[insert_pos - 1]
    next_ = route[insert_pos] if insert_pos < len(route) else 0

    # Estimate earliest possible arrival at 'cust'
    est = max(ai[cust], ai[prev] + si[prev] + t[prev][cust])
    lst = bi[cust]

    # Check if insertion affects the next node's feasibility
    if next_ != 0:
        latest_next = bi[next_] - t[cust][next_] - si[cust]
        if est > latest_next:
            return False

    return est <= lst

# === Evaluation F(X) + penalty(X) with Forward/Backward Slack for Time Windows ===
def evaluate_with_penalty(routes):
    total_cost = 0
    Feco = Fenv = Fsoc = 0
    unmet_delivery = {i: dc[i] for i in C}
    unmet_return = {i: dc_rev[i] for i in C}

    violation_penalty = 0
    penalty_tw_total = 0
    penalty_capacity_total = 0
    penalty_mv_total = 0

    for route in routes:
        if len(route) < 2:
            continue

        time = 0
        capacity = lambda_v
        load = 0  # Initial load starts at 0


        # Forward pass for earliest start times
        esi = {route[0]: 0}
        for i in range(1, len(route)):
            prev = route[i - 1]
            curr = route[i]
            travel = t[prev][curr]
            arrival = esi[prev] + si[prev] + travel
            esi[curr] = max(arrival, ai[curr])

        # Backward pass for latest start times
        lsi = {route[-1]: float('inf')}
        for i in reversed(range(len(route) - 1)):
            curr = route[i]
            succ = route[i + 1]
            travel = t[curr][succ]
            latest = lsi[succ] - si[curr] - travel
            lsi[curr] = min(latest, bi[curr])

        for i in range(1, len(route) - 1):
            curr = route[i]
            est = esi[curr]
            lst = lsi[curr]

            penalty_tw = max(0, est - bi[curr])
            penalty_tw_total += 1e3 * penalty_tw


            forward_demand = unmet_delivery[curr]
            reverse_demand = unmet_return[curr]
            
            # Serve as much forward demand as capacity allows
            
            deliverable = min(lambda_v - load, forward_demand)
            unmet_delivery[curr] -= deliverable
            
            # Then pick up as much return as possible
            pickup = min(lambda_v - load - deliverable, reverse_demand)
            unmet_return[curr] -= pickup
            
            # Update load with picked-up returns
            load += pickup
            
            # Check capacity
            if load > lambda_v:
                penalty_capacity_total += 1e6

            #deliver = min(unmet_delivery[curr], capacity)
            #capacity -= deliver
            #unmet_delivery[curr] -= deliver

            #reverse = min(unmet_return[curr], capacity)
            #capacity -= reverse
            #unmet_return[curr] -= reverse

            #if deliver + reverse > lambda_v or capacity < 0:
            #    penalty_capacity_total += 1e6

        route_time = esi[route[-1]]
        if route_time > mv:
            penalty_mv_total += 1e6

        route_feco = cv + hv * route_time + sum(t[route[i]][route[i+1]] * (cf * fv + cij) for i in range(len(route) - 1))
        route_fenv = sum(t[route[i]][route[i+1]] * ev * gamma for i in range(len(route) - 1))
        route_fsoc = route_time * hv

        Feco += route_feco
        Fenv += route_fenv
        Fsoc += route_fsoc

    Feco += pi * (sum(unmet_delivery[i] for i in C) + (1 - theta) * sum(unmet_return[i] for i in C))

    violation_penalty = penalty_tw_total + penalty_capacity_total + penalty_mv_total
    total_cost = Feco + Fenv + Fsoc + violation_penalty

    return total_cost, violation_penalty, penalty_tw_total, penalty_capacity_total, penalty_mv_total

# %%
# === Main IALNS-SA ===
def ialns_sa(initial_routes, evaluate_func, destruction_ops, repair_ops, T0=500, Tmin=0.01, cooling_rate=0.98, max_iter = 50000):
    current = copy.deepcopy(initial_routes)
    best = copy.deepcopy(current)
    best_cost, *_ = evaluate_func(best)
    temperature = T0
    objective_progress = []
    time_progress = []
    start_time = time.time()


    for it in range(max_iter):
        d_idx = select_operator(destruction_weights)
        r_idx = select_operator(repair_weights)

        removed, destroyed = destruction_ops[d_idx](copy.deepcopy(current))
        # Handle random_k_repair separately because it needs current_iter
        if r_idx == 3:
            repaired = random_k_repair(copy.deepcopy(destroyed), removed, ai, bi, si, t, dc, dc_rev, lambda_v, it)
        else:
            repaired = repair_ops[r_idx](copy.deepcopy(destroyed), removed)

        new_cost, *_ = evaluate_func(repaired)
        delta = new_cost - best_cost

        if delta < 0 or random.random() < math.exp(-delta / temperature):
            current = copy.deepcopy(repaired)
            if new_cost < best_cost:
                best = copy.deepcopy(repaired)
                best_cost = new_cost
                destruction_scores[d_idx] += 6
                repair_scores[r_idx] += 6
     
            else:
                destruction_scores[d_idx] += 3
                repair_scores[r_idx] += 3
            
        else:
            destruction_scores[d_idx] += 0
            repair_scores[r_idx] += 0
       

        destruction_usage[d_idx] += 1
        repair_usage[r_idx] += 1

        if it % 100 == 0:
            update_weights(destruction_weights, destruction_scores, destruction_usage)
            update_weights(repair_weights, repair_scores, repair_usage)

        temperature = max(Tmin, temperature * cooling_rate)

        if it % 100 == 0:
            print(f"Iter {it}: Best cost = {best_cost:.2f}, Temp = {temperature:.2f}")

        if it % 1 == 0:  # store every iteration
            objective_progress.append(best_cost)
            time_progress.append(time.time() - start_time)

    return best, best_cost, objective_progress, time_progress

# %%
initial_cost, *_ = evaluate_with_penalty(initial_routes)
print("\nInitial Solution (NNS):")
for v, r in enumerate(initial_routes):
    if r: print(f"Vehicle {v}: {r}")
print(f"Initial Cost: {initial_cost:.2f}\n")

lns_routes, lns_cost, _, _ = ialns_sa(
    initial_routes, evaluate_with_penalty, destruction_ops, repair_ops
)

print("\nFinal Solution (IALNS-SA):")
for v, r in enumerate(lns_routes):
    if r: print(f"Vehicle {v}: {r}")
print(f"Final Cost: {lns_cost:.2f}")

final_cost, penalty_final, penalty_tw, penalty_cap, penalty_mv = evaluate_with_penalty(lns_routes)
print(f"  penalty tw: {penalty_tw:.2f}, penalty_cap: {penalty_cap:.2f}, penalty_mv: {penalty_mv:.2f}, Penalty: {penalty_final:.2f}")
# Out:
# Initial Solution (NNS):
# Vehicle 0: [0, 90, 65, 66, 83, 64, 56, 95, 92, 91, 80, 94, 93, 71, 96, 0]
# Vehicle 1: [0, 69, 98, 53, 88, 55, 100, 70, 68, 61, 81, 54, 72, 41, 39, 62, 0]
# Vehicle 2: [0, 82, 99, 52, 57, 86, 74, 87, 59, 97, 75, 58, 77, 85, 0]
# Vehicle 3: [0, 67, 50, 34, 31, 29, 27, 26, 28, 30, 32, 33, 63, 73, 0]
# Vehicle 4: [0, 60, 78, 12, 14, 47, 17, 16, 15, 13, 9, 24, 20, 0]
# Vehicle 5: [0, 84, 51, 76, 89, 18, 48, 21, 23, 25, 49, 0]
# Vehicle 6: [0, 2, 6, 7, 8, 46, 4, 45, 5, 3, 1, 44, 0]
# Vehicle 7: [0, 10, 11, 79, 42, 43, 40, 36, 0]
# Vehicle 8: [0, 22, 19, 38, 37, 35, 0]
# Initial Cost: 2215321.49
#
# Iter 0: Best cost = 2215321.49, Temp = 490.00
# Iter 100: Best cost = 1707421.39, Temp = 64.98
# Iter 200: Best cost = 1555679.70, Temp = 8.62
# Iter 300: Best cost = 1403370.87, Temp = 1.14
# Iter 400: Best cost = 1378901.46, Temp = 0.15
# Iter 500: Best cost = 1307358.71, Temp = 0.02
# Iter 600: Best cost = 1304505.44, Temp = 0.01
# Iter 700: Best cost = 1304505.44, Temp = 0.01
# Iter 800: Best cost = 1304505.44, Temp = 0.01
# Iter 900: Best cost = 1304505.44, Temp = 0.01
# Iter 1000: Best cost = 1304505.44, Temp = 0.01
# Iter 1100: Best cost = 1304505.44, Temp = 0.01
# Iter 1200: Best cost = 1304505.44, Temp = 0.01
# Iter 1300: Best cost = 1304505.44, Temp = 0.01
# Iter 1400: Best cost = 1304505.44, Temp = 0.01
# Iter 1500: Best cost = 1304505.44, Temp = 0.01
# Iter 1600: Best cost = 1304505.44, Temp = 0.01
# Iter 1700: Best cost = 1304505.44, Temp = 0.01
# Iter 1800: Best cost = 1304505.44, Temp = 0.01
# Iter 1900: Best cost = 1304505.44, Temp = 0.01
# Iter 2000: Best cost = 1304505.44, Temp = 0.01
# Iter 2100: Best cost = 1304505.44, Temp = 0.01
# Iter 2200: Best cost = 1304505.44, Temp = 0.01
# Iter 2300: Best cost = 1304505.44, Temp = 0.01
# Iter 2400: Best cost = 1304505.44, Temp = 0.01
# Iter 2500: Best cost = 1304505.44, Temp = 0.01
# Iter 2600: Best cost = 1304505.44, Temp = 0.01
# Iter 2700: Best cost = 1304505.44, Temp = 0.01
# Iter 2800: Best cost = 1304505.44, Temp = 0.01
# Iter 2900: Best cost = 1304505.44, Temp = 0.01
# Iter 3000: Best cost = 1304505.44, Temp = 0.01
# Iter 3100: Best cost = 1304505.44, Temp = 0.01
# Iter 3200: Best cost = 1304505.44, Temp = 0.01
# Iter 3300: Best cost = 1304505.44, Temp = 0.01
# Iter 3400: Best cost = 1304505.44, Temp = 0.01
# Iter 3500: Best cost = 1304505.44, Temp = 0.01
# Iter 3600: Best cost = 1304505.44, Temp = 0.01
# Iter 3700: Best cost = 1304505.44, Temp = 0.01
# Iter 3800: Best cost = 1304505.44, Temp = 0.01
# Iter 3900: Best cost = 1304505.44, Temp = 0.01
# Iter 4000: Best cost = 1304505.44, Temp = 0.01
# Iter 4100: Best cost = 1304505.44, Temp = 0.01
# Iter 4200: Best cost = 1304505.44, Temp = 0.01
# Iter 4300: Best cost = 1304505.44, Temp = 0.01
# Iter 4400: Best cost = 1304505.44, Temp = 0.01
# Iter 4500: Best cost = 1304505.44, Temp = 0.01
# Iter 4600: Best cost = 1304505.44, Temp = 0.01
# Iter 4700: Best cost = 1304505.44, Temp = 0.01
# Iter 4800: Best cost = 1304505.44, Temp = 0.01
# Iter 4900: Best cost = 1304505.44, Temp = 0.01
# Iter 5000: Best cost = 1304505.44, Temp = 0.01
# Iter 5100: Best cost = 1304505.44, Temp = 0.01
# Iter 5200: Best cost = 1304505.44, Temp = 0.01
# Iter 5300: Best cost = 1304505.44, Temp = 0.01
# Iter 5400: Best cost = 1304505.44, Temp = 0.01
# Iter 5500: Best cost = 1304505.44, Temp = 0.01
# Iter 5600: Best cost = 1304505.44, Temp = 0.01
# Iter 5700: Best cost = 1304505.44, Temp = 0.01
# Iter 5800: Best cost = 1258231.77, Temp = 0.01
# Iter 5900: Best cost = 1258231.77, Temp = 0.01
# Iter 6000: Best cost = 1258231.77, Temp = 0.01
# Iter 6100: Best cost = 1258231.77, Temp = 0.01
# Iter 6200: Best cost = 1242046.17, Temp = 0.01
# Iter 6300: Best cost = 1222508.14, Temp = 0.01
# Iter 6400: Best cost = 1222508.14, Temp = 0.01
# Iter 6500: Best cost = 1222508.14, Temp = 0.01
# Iter 6600: Best cost = 1222508.14, Temp = 0.01
# Iter 6700: Best cost = 1222508.14, Temp = 0.01
# Iter 6800: Best cost = 1222508.14, Temp = 0.01
# Iter 6900: Best cost = 1222508.14, Temp = 0.01
# Iter 7000: Best cost = 1222508.14, Temp = 0.01
# Iter 7100: Best cost = 1222508.14, Temp = 0.01
# Iter 7200: Best cost = 1222508.14, Temp = 0.01
# Iter 7300: Best cost = 1222508.14, Temp = 0.01
# Iter 7400: Best cost = 1222508.14, Temp = 0.01
# Iter 7500: Best cost = 1222508.14, Temp = 0.01
# Iter 7600: Best cost = 1222508.14, Temp = 0.01
# Iter 7700: Best cost = 1159299.79, Temp = 0.01
# Iter 7800: Best cost = 1159299.79, Temp = 0.01
# Iter 7900: Best cost = 1159299.79, Temp = 0.01
# Iter 8000: Best cost = 1159299.79, Temp = 0.01
# Iter 8100: Best cost = 1159299.79, Temp = 0.01
# Iter 8200: Best cost = 1159299.79, Temp = 0.01
# Iter 8300: Best cost = 1159299.79, Temp = 0.01
# Iter 8400: Best cost = 1159299.79, Temp = 0.01
# Iter 8500: Best cost = 1159299.79, Temp = 0.01
# Iter 8600: Best cost = 1159299.79, Temp = 0.01
# Iter 8700: Best cost = 1159299.79, Temp = 0.01
# Iter 8800: Best cost = 1159299.79, Temp = 0.01
# Iter 8900: Best cost = 1159299.79, Temp = 0.01
# Iter 9000: Best cost = 1159299.79, Temp = 0.01
# Iter 9100: Best cost = 1159299.79, Temp = 0.01
# Iter 9200: Best cost = 1159299.79, Temp = 0.01
# Iter 9300: Best cost = 1159299.79, Temp = 0.01
# Iter 9400: Best cost = 1159299.79, Temp = 0.01
# Iter 9500: Best cost = 1159299.79, Temp = 0.01
# Iter 9600: Best cost = 1159299.79, Temp = 0.01
# Iter 9700: Best cost = 1159299.79, Temp = 0.01
# Iter 9800: Best cost = 1159299.79, Temp = 0.01
# Iter 9900: Best cost = 1159299.79, Temp = 0.01
# Iter 10000: Best cost = 1159299.79, Temp = 0.01
# Iter 10100: Best cost = 1159299.79, Temp = 0.01
# Iter 10200: Best cost = 1159299.79, Temp = 0.01
# Iter 10300: Best cost = 1159299.79, Temp = 0.01
# Iter 10400: Best cost = 1159299.79, Temp = 0.01
# Iter 10500: Best cost = 1159299.79, Temp = 0.01
# Iter 10600: Best cost = 1159299.79, Temp = 0.01
# Iter 10700: Best cost = 1159299.79, Temp = 0.01
# Iter 10800: Best cost = 1159299.79, Temp = 0.01
# Iter 10900: Best cost = 1159299.79, Temp = 0.01
# Iter 11000: Best cost = 1159299.79, Temp = 0.01
# Iter 11100: Best cost = 1159299.79, Temp = 0.01
# Iter 11200: Best cost = 1159299.79, Temp = 0.01
# Iter 11300: Best cost = 1159299.79, Temp = 0.01
# Iter 11400: Best cost = 1159299.79, Temp = 0.01
# Iter 11500: Best cost = 1159299.79, Temp = 0.01
# Iter 11600: Best cost = 1159299.79, Temp = 0.01
# Iter 11700: Best cost = 1159299.79, Temp = 0.01
# Iter 11800: Best cost = 1159299.79, Temp = 0.01
# Iter 11900: Best cost = 1159299.79, Temp = 0.01
# Iter 12000: Best cost = 1159299.79, Temp = 0.01
# Iter 12100: Best cost = 1159299.79, Temp = 0.01
# Iter 12200: Best cost = 1159299.79, Temp = 0.01
# Iter 12300: Best cost = 1159299.79, Temp = 0.01
# Iter 12400: Best cost = 1159299.79, Temp = 0.01
# Iter 12500: Best cost = 1159299.79, Temp = 0.01
# Iter 12600: Best cost = 1159299.79, Temp = 0.01
# Iter 12700: Best cost = 1159299.79, Temp = 0.01
# Iter 12800: Best cost = 1159299.79, Temp = 0.01
# Iter 12900: Best cost = 1159299.79, Temp = 0.01
# Iter 13000: Best cost = 1159299.79, Temp = 0.01
# Iter 13100: Best cost = 1159299.79, Temp = 0.01
# Iter 13200: Best cost = 1159299.79, Temp = 0.01
# Iter 13300: Best cost = 1159299.79, Temp = 0.01
# Iter 13400: Best cost = 1159299.79, Temp = 0.01
# Iter 13500: Best cost = 1159299.79, Temp = 0.01
# Iter 13600: Best cost = 1159299.79, Temp = 0.01
# Iter 13700: Best cost = 1159299.79, Temp = 0.01
# Iter 13800: Best cost = 1159299.79, Temp = 0.01
# Iter 13900: Best cost = 1159299.79, Temp = 0.01
# Iter 14000: Best cost = 1159299.79, Temp = 0.01
# Iter 14100: Best cost = 1159299.79, Temp = 0.01
# Iter 14200: Best cost = 1159299.79, Temp = 0.01
# Iter 14300: Best cost = 1159299.79, Temp = 0.01
# Iter 14400: Best cost = 1159299.79, Temp = 0.01
# Iter 14500: Best cost = 1159299.79, Temp = 0.01
# Iter 14600: Best cost = 1159299.79, Temp = 0.01
# Iter 14700: Best cost = 1159299.79, Temp = 0.01
# Iter 14800: Best cost = 1159299.79, Temp = 0.01
# Iter 14900: Best cost = 1159299.79, Temp = 0.01
# Iter 15000: Best cost = 1159299.79, Temp = 0.01
# Iter 15100: Best cost = 1159299.79, Temp = 0.01
# Iter 15200: Best cost = 1159299.79, Temp = 0.01
# Iter 15300: Best cost = 1159299.79, Temp = 0.01
# Iter 15400: Best cost = 1159299.79, Temp = 0.01
# Iter 15500: Best cost = 1159299.79, Temp = 0.01
# Iter 15600: Best cost = 1159299.79, Temp = 0.01
# Iter 15700: Best cost = 1159299.79, Temp = 0.01
# Iter 15800: Best cost = 1159299.79, Temp = 0.01
# Iter 15900: Best cost = 1159299.79, Temp = 0.01
# Iter 16000: Best cost = 1159299.79, Temp = 0.01
# Iter 16100: Best cost = 1159299.79, Temp = 0.01
# Iter 16200: Best cost = 1159299.79, Temp = 0.01
# Iter 16300: Best cost = 1159299.79, Temp = 0.01
# Iter 16400: Best cost = 1159299.79, Temp = 0.01
# Iter 16500: Best cost = 1159299.79, Temp = 0.01
# Iter 16600: Best cost = 1159299.79, Temp = 0.01
# Iter 16700: Best cost = 1159299.79, Temp = 0.01
# Iter 16800: Best cost = 1159299.79, Temp = 0.01
# Iter 16900: Best cost = 1159299.79, Temp = 0.01
# Iter 17000: Best cost = 1159299.79, Temp = 0.01
# Iter 17100: Best cost = 1159299.79, Temp = 0.01
# Iter 17200: Best cost = 1159299.79, Temp = 0.01
# Iter 17300: Best cost = 1159299.79, Temp = 0.01
# Iter 17400: Best cost = 1159299.79, Temp = 0.01
# Iter 17500: Best cost = 1159299.79, Temp = 0.01
# Iter 17600: Best cost = 1159299.79, Temp = 0.01
# Iter 17700: Best cost = 1159299.79, Temp = 0.01
# Iter 17800: Best cost = 1159299.79, Temp = 0.01
# Iter 17900: Best cost = 1159299.79, Temp = 0.01
# Iter 18000: Best cost = 1159299.79, Temp = 0.01
# Iter 18100: Best cost = 1159299.79, Temp = 0.01
# Iter 18200: Best cost = 1159299.79, Temp = 0.01
# Iter 18300: Best cost = 1159299.79, Temp = 0.01
# Iter 18400: Best cost = 1159299.79, Temp = 0.01
# Iter 18500: Best cost = 1159299.79, Temp = 0.01
# Iter 18600: Best cost = 1159299.79, Temp = 0.01
# Iter 18700: Best cost = 1159299.79, Temp = 0.01
# Iter 18800: Best cost = 1159299.79, Temp = 0.01
# Iter 18900: Best cost = 1159299.79, Temp = 0.01
# Iter 19000: Best cost = 1159299.79, Temp = 0.01
# Iter 19100: Best cost = 1159299.79, Temp = 0.01
# Iter 19200: Best cost = 1159299.79, Temp = 0.01
# Iter 19300: Best cost = 1159299.79, Temp = 0.01
# Iter 19400: Best cost = 1159299.79, Temp = 0.01
# Iter 19500: Best cost = 1159299.79, Temp = 0.01
# Iter 19600: Best cost = 1159299.79, Temp = 0.01
# Iter 19700: Best cost = 1159299.79, Temp = 0.01
# Iter 19800: Best cost = 1159299.79, Temp = 0.01
# Iter 19900: Best cost = 1159299.79, Temp = 0.01
# Iter 20000: Best cost = 1159299.79, Temp = 0.01
# Iter 20100: Best cost = 1159299.79, Temp = 0.01
# Iter 20200: Best cost = 1159299.79, Temp = 0.01
# Iter 20300: Best cost = 1159299.79, Temp = 0.01
# Iter 20400: Best cost = 1159299.79, Temp = 0.01
# Iter 20500: Best cost = 1159299.79, Temp = 0.01
# Iter 20600: Best cost = 1159299.79, Temp = 0.01
# Iter 20700: Best cost = 1159299.79, Temp = 0.01
# Iter 20800: Best cost = 1159299.79, Temp = 0.01
# Iter 20900: Best cost = 1159299.79, Temp = 0.01
# Iter 21000: Best cost = 1159299.79, Temp = 0.01
# Iter 21100: Best cost = 1159299.79, Temp = 0.01
# Iter 21200: Best cost = 1159299.79, Temp = 0.01
# Iter 21300: Best cost = 1159299.79, Temp = 0.01
# Iter 21400: Best cost = 1159299.79, Temp = 0.01
# Iter 21500: Best cost = 1159299.79, Temp = 0.01
# Iter 21600: Best cost = 1159299.79, Temp = 0.01
# Iter 21700: Best cost = 1159299.79, Temp = 0.01
# Iter 21800: Best cost = 1159299.79, Temp = 0.01
# Iter 21900: Best cost = 1159299.79, Temp = 0.01
# Iter 22000: Best cost = 1159299.79, Temp = 0.01
# Iter 22100: Best cost = 1159299.79, Temp = 0.01
# Iter 22200: Best cost = 1159299.79, Temp = 0.01
# Iter 22300: Best cost = 1159299.79, Temp = 0.01
# Iter 22400: Best cost = 1159299.79, Temp = 0.01
# Iter 22500: Best cost = 1159299.79, Temp = 0.01
# Iter 22600: Best cost = 1159299.79, Temp = 0.01
# Iter 22700: Best cost = 1159299.79, Temp = 0.01
# Iter 22800: Best cost = 1159299.79, Temp = 0.01
# Iter 22900: Best cost = 1159299.79, Temp = 0.01
# Iter 23000: Best cost = 1159299.79, Temp = 0.01
# Iter 23100: Best cost = 1159299.79, Temp = 0.01
# Iter 23200: Best cost = 1159299.79, Temp = 0.01
# Iter 23300: Best cost = 1159299.79, Temp = 0.01
# Iter 23400: Best cost = 1159299.79, Temp = 0.01
# Iter 23500: Best cost = 1159299.79, Temp = 0.01
# Iter 23600: Best cost = 1159299.79, Temp = 0.01
# Iter 23700: Best cost = 1159299.79, Temp = 0.01
# Iter 23800: Best cost = 1159299.79, Temp = 0.01
# Iter 23900: Best cost = 1159299.79, Temp = 0.01
# Iter 24000: Best cost = 1159299.79, Temp = 0.01
# Iter 24100: Best cost = 1159299.79, Temp = 0.01
# Iter 24200: Best cost = 1159299.79, Temp = 0.01
# Iter 24300: Best cost = 1159299.79, Temp = 0.01
# Iter 24400: Best cost = 1159299.79, Temp = 0.01
# Iter 24500: Best cost = 1159299.79, Temp = 0.01
# Iter 24600: Best cost = 1159299.79, Temp = 0.01
# Iter 24700: Best cost = 1159299.79, Temp = 0.01
# Iter 24800: Best cost = 1159299.79, Temp = 0.01
# Iter 24900: Best cost = 1159299.79, Temp = 0.01
# Iter 25000: Best cost = 1159299.79, Temp = 0.01
# Iter 25100: Best cost = 1159299.79, Temp = 0.01
# Iter 25200: Best cost = 1159299.79, Temp = 0.01
# Iter 25300: Best cost = 1159299.79, Temp = 0.01
# Iter 25400: Best cost = 1159299.79, Temp = 0.01
# Iter 25500: Best cost = 1159299.79, Temp = 0.01
# Iter 25600: Best cost = 1159299.79, Temp = 0.01
# Iter 25700: Best cost = 1159299.79, Temp = 0.01
# Iter 25800: Best cost = 1159299.79, Temp = 0.01
# Iter 25900: Best cost = 1159299.79, Temp = 0.01
# Iter 26000: Best cost = 1159299.79, Temp = 0.01
# Iter 26100: Best cost = 1159299.79, Temp = 0.01
# Iter 26200: Best cost = 1159299.79, Temp = 0.01
# Iter 26300: Best cost = 1159299.79, Temp = 0.01
# Iter 26400: Best cost = 1159299.79, Temp = 0.01
# Iter 26500: Best cost = 1159299.79, Temp = 0.01
# Iter 26600: Best cost = 1159299.79, Temp = 0.01
# Iter 26700: Best cost = 1159299.79, Temp = 0.01
# Iter 26800: Best cost = 1159299.79, Temp = 0.01
# Iter 26900: Best cost = 1159299.79, Temp = 0.01
# Iter 27000: Best cost = 1159299.79, Temp = 0.01
# Iter 27100: Best cost = 1159299.79, Temp = 0.01
# Iter 27200: Best cost = 1159299.79, Temp = 0.01
# Iter 27300: Best cost = 1159299.79, Temp = 0.01
# Iter 27400: Best cost = 1159299.79, Temp = 0.01
# Iter 27500: Best cost = 1159299.79, Temp = 0.01
# Iter 27600: Best cost = 1159299.79, Temp = 0.01
# Iter 27700: Best cost = 1159299.79, Temp = 0.01
# Iter 27800: Best cost = 1159299.79, Temp = 0.01
# Iter 27900: Best cost = 1159299.79, Temp = 0.01
# Iter 28000: Best cost = 1159299.79, Temp = 0.01
# Iter 28100: Best cost = 1159299.79, Temp = 0.01
# Iter 28200: Best cost = 1159299.79, Temp = 0.01
# Iter 28300: Best cost = 1159299.79, Temp = 0.01
# Iter 28400: Best cost = 1159299.79, Temp = 0.01
# Iter 28500: Best cost = 1159299.79, Temp = 0.01
# Iter 28600: Best cost = 1159299.79, Temp = 0.01
# Iter 28700: Best cost = 1159299.79, Temp = 0.01
# Iter 28800: Best cost = 1159299.79, Temp = 0.01
# Iter 28900: Best cost = 1159299.79, Temp = 0.01
# Iter 29000: Best cost = 1159299.79, Temp = 0.01
# Iter 29100: Best cost = 1159299.79, Temp = 0.01
# Iter 29200: Best cost = 1159299.79, Temp = 0.01
# Iter 29300: Best cost = 1159299.79, Temp = 0.01
# Iter 29400: Best cost = 1159299.79, Temp = 0.01
# Iter 29500: Best cost = 1159299.79, Temp = 0.01
# Iter 29600: Best cost = 1159299.79, Temp = 0.01
# Iter 29700: Best cost = 1159299.79, Temp = 0.01
# Iter 29800: Best cost = 1159299.79, Temp = 0.01
# Iter 29900: Best cost = 1159299.79, Temp = 0.01
# Iter 30000: Best cost = 1159299.79, Temp = 0.01
# Iter 30100: Best cost = 1159299.79, Temp = 0.01
# Iter 30200: Best cost = 1159299.79, Temp = 0.01
# Iter 30300: Best cost = 1159299.79, Temp = 0.01
# Iter 30400: Best cost = 1159299.79, Temp = 0.01
# Iter 30500: Best cost = 1159299.79, Temp = 0.01
# Iter 30600: Best cost = 1159299.79, Temp = 0.01
# Iter 30700: Best cost = 1159299.79, Temp = 0.01
# Iter 30800: Best cost = 1159299.79, Temp = 0.01
# Iter 30900: Best cost = 1159299.79, Temp = 0.01
# Iter 31000: Best cost = 1159299.79, Temp = 0.01
# Iter 31100: Best cost = 1159299.79, Temp = 0.01
# Iter 31200: Best cost = 1159299.79, Temp = 0.01
# Iter 31300: Best cost = 1159299.79, Temp = 0.01
# Iter 31400: Best cost = 1159299.79, Temp = 0.01
# Iter 31500: Best cost = 1159299.79, Temp = 0.01
# Iter 31600: Best cost = 1159299.79, Temp = 0.01
# Iter 31700: Best cost = 1159299.79, Temp = 0.01
# Iter 31800: Best cost = 1159299.79, Temp = 0.01
# Iter 31900: Best cost = 1159299.79, Temp = 0.01
# Iter 32000: Best cost = 1159299.79, Temp = 0.01
# Iter 32100: Best cost = 1159299.79, Temp = 0.01
# Iter 32200: Best cost = 1159299.79, Temp = 0.01
# Iter 32300: Best cost = 1159299.79, Temp = 0.01
# Iter 32400: Best cost = 1159299.79, Temp = 0.01
# Iter 32500: Best cost = 1159299.79, Temp = 0.01
# Iter 32600: Best cost = 1159299.79, Temp = 0.01
# Iter 32700: Best cost = 1159299.79, Temp = 0.01
# Iter 32800: Best cost = 1159299.79, Temp = 0.01
# Iter 32900: Best cost = 1159299.79, Temp = 0.01
# Iter 33000: Best cost = 1159299.79, Temp = 0.01
# Iter 33100: Best cost = 1159299.79, Temp = 0.01
# Iter 33200: Best cost = 1159299.79, Temp = 0.01
# Iter 33300: Best cost = 1159299.79, Temp = 0.01
# Iter 33400: Best cost = 1159299.79, Temp = 0.01
# Iter 33500: Best cost = 1159299.79, Temp = 0.01
# Iter 33600: Best cost = 1159299.79, Temp = 0.01
# Iter 33700: Best cost = 1159299.79, Temp = 0.01
# Iter 33800: Best cost = 1159299.79, Temp = 0.01
# Iter 33900: Best cost = 1159299.79, Temp = 0.01
# Iter 34000: Best cost = 1159299.79, Temp = 0.01
# Iter 34100: Best cost = 1159299.79, Temp = 0.01
# Iter 34200: Best cost = 1159299.79, Temp = 0.01
# Iter 34300: Best cost = 1159299.79, Temp = 0.01
# Iter 34400: Best cost = 1159299.79, Temp = 0.01
# Iter 34500: Best cost = 1159299.79, Temp = 0.01
# Iter 34600: Best cost = 1159299.79, Temp = 0.01
# Iter 34700: Best cost = 1159299.79, Temp = 0.01
# Iter 34800: Best cost = 1159299.79, Temp = 0.01
# Iter 34900: Best cost = 1159299.79, Temp = 0.01
# Iter 35000: Best cost = 1159299.79, Temp = 0.01
# Iter 35100: Best cost = 1159299.79, Temp = 0.01
# Iter 35200: Best cost = 1159299.79, Temp = 0.01
# Iter 35300: Best cost = 1159299.79, Temp = 0.01
# Iter 35400: Best cost = 1159299.79, Temp = 0.01
# Iter 35500: Best cost = 1095874.28, Temp = 0.01
# Iter 35600: Best cost = 1095874.28, Temp = 0.01
# Iter 35700: Best cost = 1095874.28, Temp = 0.01
# Iter 35800: Best cost = 1095874.28, Temp = 0.01
# Iter 35900: Best cost = 1095874.28, Temp = 0.01
# Iter 36000: Best cost = 1095874.28, Temp = 0.01
# Iter 36100: Best cost = 1095874.28, Temp = 0.01
# Iter 36200: Best cost = 1095874.28, Temp = 0.01
# Iter 36300: Best cost = 1095874.28, Temp = 0.01
# Iter 36400: Best cost = 1095874.28, Temp = 0.01
# Iter 36500: Best cost = 1095874.28, Temp = 0.01
# Iter 36600: Best cost = 1095874.28, Temp = 0.01
# Iter 36700: Best cost = 1095874.28, Temp = 0.01
# Iter 36800: Best cost = 1095874.28, Temp = 0.01
# Iter 36900: Best cost = 1095874.28, Temp = 0.01
# Iter 37000: Best cost = 1095874.28, Temp = 0.01
# Iter 37100: Best cost = 1095874.28, Temp = 0.01
# Iter 37200: Best cost = 1095874.28, Temp = 0.01
# Iter 37300: Best cost = 1095874.28, Temp = 0.01
# Iter 37400: Best cost = 1095874.28, Temp = 0.01
# Iter 37500: Best cost = 1086421.79, Temp = 0.01
# Iter 37600: Best cost = 1086421.79, Temp = 0.01
# Iter 37700: Best cost = 1086421.79, Temp = 0.01
# Iter 37800: Best cost = 1086421.79, Temp = 0.01
# Iter 37900: Best cost = 1086421.79, Temp = 0.01
# Iter 38000: Best cost = 1086421.79, Temp = 0.01
# Iter 38100: Best cost = 1086421.79, Temp = 0.01
# Iter 38200: Best cost = 1086421.79, Temp = 0.01
# Iter 38300: Best cost = 1086421.79, Temp = 0.01
# Iter 38400: Best cost = 1086421.79, Temp = 0.01
# Iter 38500: Best cost = 1086421.79, Temp = 0.01
# Iter 38600: Best cost = 1086421.79, Temp = 0.01
# Iter 38700: Best cost = 1086421.79, Temp = 0.01
# Iter 38800: Best cost = 1086421.79, Temp = 0.01
# Iter 38900: Best cost = 1086421.79, Temp = 0.01
# Iter 39000: Best cost = 1086421.79, Temp = 0.01
# Iter 39100: Best cost = 1086421.79, Temp = 0.01
# Iter 39200: Best cost = 1086421.79, Temp = 0.01
# Iter 39300: Best cost = 1086421.79, Temp = 0.01
# Iter 39400: Best cost = 1086421.79, Temp = 0.01
# Iter 39500: Best cost = 1086421.79, Temp = 0.01
# Iter 39600: Best cost = 1086421.79, Temp = 0.01
# Iter 39700: Best cost = 1086421.79, Temp = 0.01
# Iter 39800: Best cost = 1086421.79, Temp = 0.01
# Iter 39900: Best cost = 1086421.79, Temp = 0.01
# Iter 40000: Best cost = 1086421.79, Temp = 0.01
# Iter 40100: Best cost = 1086421.79, Temp = 0.01
# Iter 40200: Best cost = 1086421.79, Temp = 0.01
# Iter 40300: Best cost = 1086421.79, Temp = 0.01
# Iter 40400: Best cost = 1086421.79, Temp = 0.01
# Iter 40500: Best cost = 1086421.79, Temp = 0.01
# Iter 40600: Best cost = 1086421.79, Temp = 0.01
# Iter 40700: Best cost = 1086421.79, Temp = 0.01
# Iter 40800: Best cost = 1086421.79, Temp = 0.01
# Iter 40900: Best cost = 1086421.79, Temp = 0.01
# Iter 41000: Best cost = 1086421.79, Temp = 0.01
# Iter 41100: Best cost = 1086421.79, Temp = 0.01
# Iter 41200: Best cost = 1086421.79, Temp = 0.01
# Iter 41300: Best cost = 1086421.79, Temp = 0.01
# Iter 41400: Best cost = 1086421.79, Temp = 0.01
# Iter 41500: Best cost = 1086421.79, Temp = 0.01
# Iter 41600: Best cost = 1086421.79, Temp = 0.01
# Iter 41700: Best cost = 1086421.79, Temp = 0.01
# Iter 41800: Best cost = 1086421.79, Temp = 0.01
# Iter 41900: Best cost = 1086421.79, Temp = 0.01
# Iter 42000: Best cost = 1086421.79, Temp = 0.01
# Iter 42100: Best cost = 1086421.79, Temp = 0.01
# Iter 42200: Best cost = 1086421.79, Temp = 0.01
# Iter 42300: Best cost = 1086421.79, Temp = 0.01
# Iter 42400: Best cost = 1086421.79, Temp = 0.01
# Iter 42500: Best cost = 1086421.79, Temp = 0.01
# Iter 42600: Best cost = 1086421.79, Temp = 0.01
# Iter 42700: Best cost = 1086421.79, Temp = 0.01
# Iter 42800: Best cost = 1086421.79, Temp = 0.01
# Iter 42900: Best cost = 1086421.79, Temp = 0.01
# Iter 43000: Best cost = 1086421.79, Temp = 0.01
# Iter 43100: Best cost = 1086421.79, Temp = 0.01
# Iter 43200: Best cost = 1086421.79, Temp = 0.01
# Iter 43300: Best cost = 1086421.79, Temp = 0.01
# Iter 43400: Best cost = 1086421.79, Temp = 0.01
# Iter 43500: Best cost = 1086421.79, Temp = 0.01
# Iter 43600: Best cost = 1086421.79, Temp = 0.01
# Iter 43700: Best cost = 1086421.79, Temp = 0.01
# Iter 43800: Best cost = 1086421.79, Temp = 0.01
# Iter 43900: Best cost = 1086421.79, Temp = 0.01
# Iter 44000: Best cost = 1086421.79, Temp = 0.01
# Iter 44100: Best cost = 1086421.79, Temp = 0.01
# Iter 44200: Best cost = 1086421.79, Temp = 0.01
# Iter 44300: Best cost = 1086421.79, Temp = 0.01
# Iter 44400: Best cost = 1086421.79, Temp = 0.01
# Iter 44500: Best cost = 1086421.79, Temp = 0.01
# Iter 44600: Best cost = 1086421.79, Temp = 0.01
# Iter 44700: Best cost = 1086421.79, Temp = 0.01
# Iter 44800: Best cost = 1086421.79, Temp = 0.01
# Iter 44900: Best cost = 1086421.79, Temp = 0.01
# Iter 45000: Best cost = 1086421.79, Temp = 0.01
# Iter 45100: Best cost = 1086421.79, Temp = 0.01
# Iter 45200: Best cost = 1086421.79, Temp = 0.01
# Iter 45300: Best cost = 1086421.79, Temp = 0.01
# Iter 45400: Best cost = 1086421.79, Temp = 0.01
# Iter 45500: Best cost = 1086421.79, Temp = 0.01
# Iter 45600: Best cost = 1086421.79, Temp = 0.01
# Iter 45700: Best cost = 1086421.79, Temp = 0.01
# Iter 45800: Best cost = 1086421.79, Temp = 0.01
# Iter 45900: Best cost = 1086421.79, Temp = 0.01
# Iter 46000: Best cost = 1086421.79, Temp = 0.01
# Iter 46100: Best cost = 1086421.79, Temp = 0.01
# Iter 46200: Best cost = 1086421.79, Temp = 0.01
# Iter 46300: Best cost = 1086421.79, Temp = 0.01
# Iter 46400: Best cost = 1086421.79, Temp = 0.01
# Iter 46500: Best cost = 1086421.79, Temp = 0.01
# Iter 46600: Best cost = 1086421.79, Temp = 0.01
# Iter 46700: Best cost = 1086421.79, Temp = 0.01
# Iter 46800: Best cost = 1086421.79, Temp = 0.01
# Iter 46900: Best cost = 1086421.79, Temp = 0.01
# Iter 47000: Best cost = 1086421.79, Temp = 0.01
# Iter 47100: Best cost = 1086421.79, Temp = 0.01
# Iter 47200: Best cost = 1086421.79, Temp = 0.01
# Iter 47300: Best cost = 1086421.79, Temp = 0.01
# Iter 47400: Best cost = 1086421.79, Temp = 0.01
# Iter 47500: Best cost = 1086421.79, Temp = 0.01
# Iter 47600: Best cost = 1086421.79, Temp = 0.01
# Iter 47700: Best cost = 1086421.79, Temp = 0.01
# Iter 47800: Best cost = 1086421.79, Temp = 0.01
# Iter 47900: Best cost = 1086421.79, Temp = 0.01
# Iter 48000: Best cost = 1086421.79, Temp = 0.01
# Iter 48100: Best cost = 1086421.79, Temp = 0.01
# Iter 48200: Best cost = 1086421.79, Temp = 0.01
# Iter 48300: Best cost = 1086421.79, Temp = 0.01
# Iter 48400: Best cost = 1086421.79, Temp = 0.01
# Iter 48500: Best cost = 1086421.79, Temp = 0.01
# Iter 48600: Best cost = 1086421.79, Temp = 0.01
# Iter 48700: Best cost = 1086421.79, Temp = 0.01
# Iter 48800: Best cost = 1086421.79, Temp = 0.01
# Iter 48900: Best cost = 1086421.79, Temp = 0.01
# Iter 49000: Best cost = 1086421.79, Temp = 0.01
# Iter 49100: Best cost = 1086421.79, Temp = 0.01
# Iter 49200: Best cost = 1086421.79, Temp = 0.01
# Iter 49300: Best cost = 1086421.79, Temp = 0.01
# Iter 49400: Best cost = 1086421.79, Temp = 0.01
# Iter 49500: Best cost = 1086421.79, Temp = 0.01
# Iter 49600: Best cost = 1086421.79, Temp = 0.01
# Iter 49700: Best cost = 1086421.79, Temp = 0.01
# Iter 49800: Best cost = 1086421.79, Temp = 0.01
# Iter 49900: Best cost = 1086421.79, Temp = 0.01
#
# Final Solution (IALNS-SA):
# Vehicle 0: [0, 91, 94, 93, 71, 96, 0]
# Vehicle 1: [0, 69, 98, 53, 88, 55, 0]
# Vehicle 2: [0, 90, 82, 99, 52, 57, 86, 74, 87, 59, 97, 75, 58, 77, 65, 0]
# Vehicle 3: [0, 80, 50, 34, 31, 29, 27, 26, 28, 30, 32, 33, 63, 85, 84, 56, 0]
# Vehicle 4: [0, 60, 78, 73, 47, 17, 16, 15, 11, 9, 13, 10, 14, 12, 0]
# Vehicle 5: [0, 66, 64, 51, 76, 89, 18, 48, 21, 23, 25, 19, 49, 20, 22, 24, 83, 0]
# Vehicle 6: [0, 70, 2, 6, 7, 79, 8, 46, 4, 45, 5, 3, 1, 100, 0]
# Vehicle 7: [0, 37, 35, 36, 40, 43, 44, 42, 61, 68, 0]
# Vehicle 8: [0, 92, 95, 62, 67, 38, 39, 41, 72, 54, 81, 0]
# Final Cost: 1086421.79
#   penalty tw: 991923.09, penalty_cap: 0.00, penalty_mv: 0.00, Penalty: 991923.09

# %%
destruction_op_names = ['Random Destroy', 'Similarity Destroy', 'Max Saving Destroy', 'Max Wait Destroy', 'Destroy Route']
repair_op_names = ['Global Optimal Repair', 'Min Insertion Cost', 'Regret Repair', 'Random-k Repair', 'Min Waiting Time']

# Operator usage summary
print("\n=== Operator Usage Summary ===")

print("\nDestruction Operators Usage:")
for idx, count in enumerate(destruction_usage):
    print(f"  D{idx+1} - {destruction_op_names[idx]}: used {count} times")

print("\nRepair Operators Usage:")
for idx, count in enumerate(repair_usage):
    print(f"  R{idx+1} - {repair_op_names[idx]}: used {count} times")
# Out:
# === Operator Usage Summary ===
#
# Destruction Operators Usage:
#   D1 - Random Destroy: used 1 times
#   D2 - Similarity Destroy: used 100 times
#   D3 - Max Saving Destroy: used 1 times
#   D4 - Max Wait Destroy: used 1 times
#   D5 - Destroy Route: used 1 times
#
# Repair Operators Usage:
#   R1 - Global Optimal Repair: used 26 times
#   R2 - Min Insertion Cost: used 42 times
#   R3 - Regret Repair: used 34 times
#   R4 - Random-k Repair: used 1 times
#   R5 - Min Waiting Time: used 1 times

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def plot_metaheuristic_routes(routes, coords, V):
    # Extract X and Y coordinates
    xc = [c[0] for c in coords]
    yc = [c[1] for c in coords]

    plt.figure(figsize=(15, 15))
    plt.scatter(xc, yc, c='red', label='Customers')
    plt.scatter(xc[0], yc[0], c='green', marker='s', label='Depot')

    for i, (x, y_) in enumerate(zip(xc, yc)):
        plt.annotate(str(i), (x, y_), textcoords="offset points", xytext=(0, 10), ha='center', fontsize=10)

    cmap = plt.get_cmap('tab20', len(V))
    used_vehicle_count = 0

    for v, route in enumerate(routes):
        if not route or len(route) < 2:
            continue
        used_vehicle_count += 1
        color = cmap(v % 20)

        for i in range(len(route) - 1):
            a, b = route[i], route[i + 1]
            plt.arrow(xc[a], yc[a], xc[b] - xc[a], yc[b] - yc[a],
                      color=color, head_width=0.4, length_includes_head=True, alpha=0.7)

        plt.plot([], [], color=color, label=f'Vehicle {v}')

    plt.xlabel('X Coordinate', fontsize=14)
    plt.ylabel('Y Coordinate', fontsize=14)
    plt.title(f'Routes of {used_vehicle_count} Used Vehicles (Metaheuristic)', fontsize=18)
    plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1), fontsize=10)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Call the function
plot_metaheuristic_routes(lns_routes, coords, V)

# %%
import matplotlib.pyplot as plt

def plot_vehicle_load_dynamics(routes, dc, dc_rev, lambda_v):
    for v, route in enumerate(routes):
        if not route or len(route) < 3:
            continue  # Skip empty or trivial routes

        cust_nodes = []
        remaining_load = []
        cumulative_reverse = []
        net_vehicle_load = []

        load = sum(dc[node] for node in route if node != 0)  # Start with total forward delivery
        rev_total = 0

        for i in range(1, len(route) - 1):  # skip depot at start/end
            node = route[i]
            forward = dc[node]
            reverse = dc_rev[node]

            load -= forward                 # Deliver forward demand
            rev_total += reverse            # Pickup reverse demand
            net_load = load + rev_total     # Net load carried by vehicle

            cust_nodes.append(str(node))
            remaining_load.append(load)
            cumulative_reverse.append(rev_total)
            net_vehicle_load.append(net_load)

        plt.figure(figsize=(12, 6))
        plt.plot(cust_nodes, remaining_load, marker='o', label='Remaining Forward Load', color='blue')
        plt.plot(cust_nodes, cumulative_reverse, marker='s', label='Cumulative Reverse Pickup', color='orange')
        plt.plot(cust_nodes, net_vehicle_load, marker='^', label='Net Vehicle Load', color='green')
        plt.axhline(y=lambda_v, color='red', linestyle='--', label=f'Capacity ({lambda_v})', alpha=0.6)

        # Optional: annotate points
        for idx in range(len(cust_nodes)):
            plt.text(cust_nodes[idx], net_vehicle_load[idx] + 2, f'{net_vehicle_load[idx]:.0f}', ha='center', fontsize=8, color='green')

        plt.title(f'Vehicle Load Dynamics - Vehicle {v}', fontsize=14)
        plt.xlabel('Customer Node', fontsize=12)
        plt.ylabel('Quantity', fontsize=12)
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# %%
plot_vehicle_load_dynamics(initial_routes, dc, dc_rev, lambda_v)

# %%
def plot_objective_over_time(iterations, times):
    plt.figure(figsize=(12, 6))
    plt.plot(iterations, label="Objective Value")
    plt.xlabel("Iteration")
    plt.ylabel("Objective Value")
    plt.title("Objective Value Progress Over Iterations")
    plt.grid(True)
    plt.legend()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.plot(times, iterations, label="Objective vs Time")
    plt.xlabel("Time (s)")
    plt.ylabel("Objective Value")
    plt.title("Objective Value vs Time")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
lns_routes, lns_cost, obj_history, time_history = ialns_sa(
    initial_routes, evaluate_with_penalty, destruction_ops, repair_ops
)

plot_objective_over_time(obj_history, time_history)
# Out:
# Iter 0: Best cost = 2215321.49, Temp = 490.00
# Iter 100: Best cost = 1358997.02, Temp = 64.98
# Iter 200: Best cost = 1252321.27, Temp = 8.62
# Iter 300: Best cost = 1212539.98, Temp = 1.14
# Iter 400: Best cost = 1212539.98, Temp = 0.15
# Iter 500: Best cost = 1183032.68, Temp = 0.02
# Iter 600: Best cost = 1110154.98, Temp = 0.01
# Iter 700: Best cost = 1084489.06, Temp = 0.01
# Iter 800: Best cost = 1084346.41, Temp = 0.01
# Iter 900: Best cost = 1084346.41, Temp = 0.01
# Iter 1000: Best cost = 998732.56, Temp = 0.01
# Iter 1100: Best cost = 998732.56, Temp = 0.01
# Iter 1200: Best cost = 998732.56, Temp = 0.01
# Iter 1300: Best cost = 947017.34, Temp = 0.01
# Iter 1400: Best cost = 947017.34, Temp = 0.01
# Iter 1500: Best cost = 947017.34, Temp = 0.01
# Iter 1600: Best cost = 947017.34, Temp = 0.01
# Iter 1700: Best cost = 947017.34, Temp = 0.01
# Iter 1800: Best cost = 924636.47, Temp = 0.01
# Iter 1900: Best cost = 924636.47, Temp = 0.01
# Iter 2000: Best cost = 924636.47, Temp = 0.01
# Iter 2100: Best cost = 924636.47, Temp = 0.01
# Iter 2200: Best cost = 924636.47, Temp = 0.01
# Iter 2300: Best cost = 924636.47, Temp = 0.01
# Iter 2400: Best cost = 924636.47, Temp = 0.01
# Iter 2500: Best cost = 924636.47, Temp = 0.01
# Iter 2600: Best cost = 924636.47, Temp = 0.01
# Iter 2700: Best cost = 924636.47, Temp = 0.01
# Iter 2800: Best cost = 924636.47, Temp = 0.01
# Iter 2900: Best cost = 924636.47, Temp = 0.01
# Iter 3000: Best cost = 924636.47, Temp = 0.01
# Iter 3100: Best cost = 924636.47, Temp = 0.01
# Iter 3200: Best cost = 924636.47, Temp = 0.01
# Iter 3300: Best cost = 924636.47, Temp = 0.01
# Iter 3400: Best cost = 924636.47, Temp = 0.01
# Iter 3500: Best cost = 924636.47, Temp = 0.01
# Iter 3600: Best cost = 924636.47, Temp = 0.01
# Iter 3700: Best cost = 924636.47, Temp = 0.01
# Iter 3800: Best cost = 924636.47, Temp = 0.01
# Iter 3900: Best cost = 924636.47, Temp = 0.01
# Iter 4000: Best cost = 924636.47, Temp = 0.01
# Iter 4100: Best cost = 924636.47, Temp = 0.01
# Iter 4200: Best cost = 924636.47, Temp = 0.01
# Iter 4300: Best cost = 924636.47, Temp = 0.01
# Iter 4400: Best cost = 924636.47, Temp = 0.01
# Iter 4500: Best cost = 924636.47, Temp = 0.01
# Iter 4600: Best cost = 924636.47, Temp = 0.01
# Iter 4700: Best cost = 924636.47, Temp = 0.01
# Iter 4800: Best cost = 924636.47, Temp = 0.01
# Iter 4900: Best cost = 924636.47, Temp = 0.01
# Iter 5000: Best cost = 924636.47, Temp = 0.01
# Iter 5100: Best cost = 924636.47, Temp = 0.01
# Iter 5200: Best cost = 924636.47, Temp = 0.01
# Iter 5300: Best cost = 924636.47, Temp = 0.01
# Iter 5400: Best cost = 924636.47, Temp = 0.01
# Iter 5500: Best cost = 924636.47, Temp = 0.01
# Iter 5600: Best cost = 924636.47, Temp = 0.01
# Iter 5700: Best cost = 924636.47, Temp = 0.01
# Iter 5800: Best cost = 924636.47, Temp = 0.01
# Iter 5900: Best cost = 924636.47, Temp = 0.01
# Iter 6000: Best cost = 924636.47, Temp = 0.01
# Iter 6100: Best cost = 924636.47, Temp = 0.01
# Iter 6200: Best cost = 924636.47, Temp = 0.01
# Iter 6300: Best cost = 924636.47, Temp = 0.01
# Iter 6400: Best cost = 924636.47, Temp = 0.01
# Iter 6500: Best cost = 924636.47, Temp = 0.01
# Iter 6600: Best cost = 924636.47, Temp = 0.01
# Iter 6700: Best cost = 924636.47, Temp = 0.01
# Iter 6800: Best cost = 924636.47, Temp = 0.01
# Iter 6900: Best cost = 924636.47, Temp = 0.01
# Iter 7000: Best cost = 924636.47, Temp = 0.01
# Iter 7100: Best cost = 924636.47, Temp = 0.01
# Iter 7200: Best cost = 924636.47, Temp = 0.01
# Iter 7300: Best cost = 924636.47, Temp = 0.01
# Iter 7400: Best cost = 924636.47, Temp = 0.01
# Iter 7500: Best cost = 924636.47, Temp = 0.01
# Iter 7600: Best cost = 924636.47, Temp = 0.01
# Iter 7700: Best cost = 924636.47, Temp = 0.01
# Iter 7800: Best cost = 924636.47, Temp = 0.01
# Iter 7900: Best cost = 924636.47, Temp = 0.01
# Iter 8000: Best cost = 924636.47, Temp = 0.01
# Iter 8100: Best cost = 924636.47, Temp = 0.01
# Iter 8200: Best cost = 924636.47, Temp = 0.01
# Iter 8300: Best cost = 924636.47, Temp = 0.01
# Iter 8400: Best cost = 924636.47, Temp = 0.01
# Iter 8500: Best cost = 924636.47, Temp = 0.01
# Iter 8600: Best cost = 924636.47, Temp = 0.01
# Iter 8700: Best cost = 924636.47, Temp = 0.01
# Iter 8800: Best cost = 924636.47, Temp = 0.01
# Iter 8900: Best cost = 924636.47, Temp = 0.01
# Iter 9000: Best cost = 924636.47, Temp = 0.01
# Iter 9100: Best cost = 924636.47, Temp = 0.01
# Iter 9200: Best cost = 924636.47, Temp = 0.01
# Iter 9300: Best cost = 924636.47, Temp = 0.01
# Iter 9400: Best cost = 924636.47, Temp = 0.01
# Iter 9500: Best cost = 924636.47, Temp = 0.01
# Iter 9600: Best cost = 924636.47, Temp = 0.01
# Iter 9700: Best cost = 924636.47, Temp = 0.01
# Iter 9800: Best cost = 924636.47, Temp = 0.01
# Iter 9900: Best cost = 924636.47, Temp = 0.01
# Iter 10000: Best cost = 924636.47, Temp = 0.01
# Iter 10100: Best cost = 924636.47, Temp = 0.01
# Iter 10200: Best cost = 924636.47, Temp = 0.01
# Iter 10300: Best cost = 924636.47, Temp = 0.01
# Iter 10400: Best cost = 924636.47, Temp = 0.01
# Iter 10500: Best cost = 924636.47, Temp = 0.01
# Iter 10600: Best cost = 924636.47, Temp = 0.01
# Iter 10700: Best cost = 924636.47, Temp = 0.01
# Iter 10800: Best cost = 924636.47, Temp = 0.01
# Iter 10900: Best cost = 924636.47, Temp = 0.01
# Iter 11000: Best cost = 924636.47, Temp = 0.01
# Iter 11100: Best cost = 924636.47, Temp = 0.01
# Iter 11200: Best cost = 924636.47, Temp = 0.01
# Iter 11300: Best cost = 924636.47, Temp = 0.01
# Iter 11400: Best cost = 924636.47, Temp = 0.01
# Iter 11500: Best cost = 924636.47, Temp = 0.01
# Iter 11600: Best cost = 924636.47, Temp = 0.01
# Iter 11700: Best cost = 924636.47, Temp = 0.01
# Iter 11800: Best cost = 924636.47, Temp = 0.01
# Iter 11900: Best cost = 924636.47, Temp = 0.01
# Iter 12000: Best cost = 924636.47, Temp = 0.01
# Iter 12100: Best cost = 924636.47, Temp = 0.01
# Iter 12200: Best cost = 924636.47, Temp = 0.01
# Iter 12300: Best cost = 924636.47, Temp = 0.01
# Iter 12400: Best cost = 924636.47, Temp = 0.01
# Iter 12500: Best cost = 924636.47, Temp = 0.01
# Iter 12600: Best cost = 924636.47, Temp = 0.01
# Iter 12700: Best cost = 924636.47, Temp = 0.01
# Iter 12800: Best cost = 924636.47, Temp = 0.01
# Iter 12900: Best cost = 924636.47, Temp = 0.01
# Iter 13000: Best cost = 924636.47, Temp = 0.01
# Iter 13100: Best cost = 924636.47, Temp = 0.01
# Iter 13200: Best cost = 924636.47, Temp = 0.01
# Iter 13300: Best cost = 924636.47, Temp = 0.01
# Iter 13400: Best cost = 924636.47, Temp = 0.01
# Iter 13500: Best cost = 924636.47, Temp = 0.01
# Iter 13600: Best cost = 924636.47, Temp = 0.01
# Iter 13700: Best cost = 924636.47, Temp = 0.01
# Iter 13800: Best cost = 924636.47, Temp = 0.01
# Iter 13900: Best cost = 924636.47, Temp = 0.01
# Iter 14000: Best cost = 924636.47, Temp = 0.01
# Iter 14100: Best cost = 924636.47, Temp = 0.01
# Iter 14200: Best cost = 924636.47, Temp = 0.01
# Iter 14300: Best cost = 924636.47, Temp = 0.01
# Iter 14400: Best cost = 924636.47, Temp = 0.01
# Iter 14500: Best cost = 924636.47, Temp = 0.01
# Iter 14600: Best cost = 924636.47, Temp = 0.01
# Iter 14700: Best cost = 924636.47, Temp = 0.01
# Iter 14800: Best cost = 924636.47, Temp = 0.01
# Iter 14900: Best cost = 924636.47, Temp = 0.01
# Iter 15000: Best cost = 924636.47, Temp = 0.01
# Iter 15100: Best cost = 924636.47, Temp = 0.01
# Iter 15200: Best cost = 924636.47, Temp = 0.01
# Iter 15300: Best cost = 924636.47, Temp = 0.01
# Iter 15400: Best cost = 924636.47, Temp = 0.01
# Iter 15500: Best cost = 924636.47, Temp = 0.01
# Iter 15600: Best cost = 924636.47, Temp = 0.01
# Iter 15700: Best cost = 924636.47, Temp = 0.01
# Iter 15800: Best cost = 924636.47, Temp = 0.01
# Iter 15900: Best cost = 924636.47, Temp = 0.01
# Iter 16000: Best cost = 924636.47, Temp = 0.01
# Iter 16100: Best cost = 924636.47, Temp = 0.01
# Iter 16200: Best cost = 924636.47, Temp = 0.01
# Iter 16300: Best cost = 924636.47, Temp = 0.01
# Iter 16400: Best cost = 924636.47, Temp = 0.01
# Iter 16500: Best cost = 924636.47, Temp = 0.01
# Iter 16600: Best cost = 924636.47, Temp = 0.01
# Iter 16700: Best cost = 924636.47, Temp = 0.01
# Iter 16800: Best cost = 924636.47, Temp = 0.01
# Iter 16900: Best cost = 924636.47, Temp = 0.01
# Iter 17000: Best cost = 924636.47, Temp = 0.01
# Iter 17100: Best cost = 924636.47, Temp = 0.01
# Iter 17200: Best cost = 924636.47, Temp = 0.01
# Iter 17300: Best cost = 924636.47, Temp = 0.01
# Iter 17400: Best cost = 924636.47, Temp = 0.01
# Iter 17500: Best cost = 924636.47, Temp = 0.01
# Iter 17600: Best cost = 924636.47, Temp = 0.01
# Iter 17700: Best cost = 924636.47, Temp = 0.01
# Iter 17800: Best cost = 924636.47, Temp = 0.01
# Iter 17900: Best cost = 924636.47, Temp = 0.01
# Iter 18000: Best cost = 924636.47, Temp = 0.01
# Iter 18100: Best cost = 924636.47, Temp = 0.01
# Iter 18200: Best cost = 924636.47, Temp = 0.01
# Iter 18300: Best cost = 924636.47, Temp = 0.01
# Iter 18400: Best cost = 924636.47, Temp = 0.01
# Iter 18500: Best cost = 924636.47, Temp = 0.01
# Iter 18600: Best cost = 924636.47, Temp = 0.01
# Iter 18700: Best cost = 924636.47, Temp = 0.01
# Iter 18800: Best cost = 924636.47, Temp = 0.01
# Iter 18900: Best cost = 924636.47, Temp = 0.01
# Iter 19000: Best cost = 924636.47, Temp = 0.01
# Iter 19100: Best cost = 924636.47, Temp = 0.01
# Iter 19200: Best cost = 924636.47, Temp = 0.01
# Iter 19300: Best cost = 924636.47, Temp = 0.01
# Iter 19400: Best cost = 924636.47, Temp = 0.01
# Iter 19500: Best cost = 924636.47, Temp = 0.01
# Iter 19600: Best cost = 924636.47, Temp = 0.01
# Iter 19700: Best cost = 924636.47, Temp = 0.01
# Iter 19800: Best cost = 924636.47, Temp = 0.01
# Iter 19900: Best cost = 924636.47, Temp = 0.01
# Iter 20000: Best cost = 924636.47, Temp = 0.01
# Iter 20100: Best cost = 924636.47, Temp = 0.01
# Iter 20200: Best cost = 924636.47, Temp = 0.01
# Iter 20300: Best cost = 924636.47, Temp = 0.01
# Iter 20400: Best cost = 924636.47, Temp = 0.01
# Iter 20500: Best cost = 924636.47, Temp = 0.01
# Iter 20600: Best cost = 924636.47, Temp = 0.01
# Iter 20700: Best cost = 924636.47, Temp = 0.01
# Iter 20800: Best cost = 924636.47, Temp = 0.01
# Iter 20900: Best cost = 924636.47, Temp = 0.01
# Iter 21000: Best cost = 924636.47, Temp = 0.01
# Iter 21100: Best cost = 924636.47, Temp = 0.01
# Iter 21200: Best cost = 924636.47, Temp = 0.01
# Iter 21300: Best cost = 924636.47, Temp = 0.01
# Iter 21400: Best cost = 924636.47, Temp = 0.01
# Iter 21500: Best cost = 924636.47, Temp = 0.01
# Iter 21600: Best cost = 924636.47, Temp = 0.01
# Iter 21700: Best cost = 924636.47, Temp = 0.01
# Iter 21800: Best cost = 924636.47, Temp = 0.01
# Iter 21900: Best cost = 924636.47, Temp = 0.01
# Iter 22000: Best cost = 924636.47, Temp = 0.01
# Iter 22100: Best cost = 924636.47, Temp = 0.01
# Iter 22200: Best cost = 924636.47, Temp = 0.01
# Iter 22300: Best cost = 924636.47, Temp = 0.01
# Iter 22400: Best cost = 924636.47, Temp = 0.01
# Iter 22500: Best cost = 924636.47, Temp = 0.01
# Iter 22600: Best cost = 924636.47, Temp = 0.01
# Iter 22700: Best cost = 924636.47, Temp = 0.01
# Iter 22800: Best cost = 924636.47, Temp = 0.01
# Iter 22900: Best cost = 924636.47, Temp = 0.01
# Iter 23000: Best cost = 924636.47, Temp = 0.01
# Iter 23100: Best cost = 924636.47, Temp = 0.01
# Iter 23200: Best cost = 924636.47, Temp = 0.01
# Iter 23300: Best cost = 924636.47, Temp = 0.01
# Iter 23400: Best cost = 924636.47, Temp = 0.01
# Iter 23500: Best cost = 924636.47, Temp = 0.01
# Iter 23600: Best cost = 924636.47, Temp = 0.01
# Iter 23700: Best cost = 924636.47, Temp = 0.01
# Iter 23800: Best cost = 924636.47, Temp = 0.01
# Iter 23900: Best cost = 924636.47, Temp = 0.01
# Iter 24000: Best cost = 924636.47, Temp = 0.01
# Iter 24100: Best cost = 924636.47, Temp = 0.01
# Iter 24200: Best cost = 924636.47, Temp = 0.01
# Iter 24300: Best cost = 924636.47, Temp = 0.01
# Iter 24400: Best cost = 924636.47, Temp = 0.01
# Iter 24500: Best cost = 924636.47, Temp = 0.01
# Iter 24600: Best cost = 924636.47, Temp = 0.01
# Iter 24700: Best cost = 924636.47, Temp = 0.01
# Iter 24800: Best cost = 924636.47, Temp = 0.01
# Iter 24900: Best cost = 924636.47, Temp = 0.01
# Iter 25000: Best cost = 924636.47, Temp = 0.01
# Iter 25100: Best cost = 924636.47, Temp = 0.01
# Iter 25200: Best cost = 924636.47, Temp = 0.01
# Iter 25300: Best cost = 924636.47, Temp = 0.01
# Iter 25400: Best cost = 924636.47, Temp = 0.01
# Iter 25500: Best cost = 924636.47, Temp = 0.01
# Iter 25600: Best cost = 924636.47, Temp = 0.01
# Iter 25700: Best cost = 924636.47, Temp = 0.01
# Iter 25800: Best cost = 924636.47, Temp = 0.01
# Iter 25900: Best cost = 924636.47, Temp = 0.01
# Iter 26000: Best cost = 924636.47, Temp = 0.01
# Iter 26100: Best cost = 924636.47, Temp = 0.01
# Iter 26200: Best cost = 924636.47, Temp = 0.01
# Iter 26300: Best cost = 924636.47, Temp = 0.01
# Iter 26400: Best cost = 924636.47, Temp = 0.01
# Iter 26500: Best cost = 924636.47, Temp = 0.01
# Iter 26600: Best cost = 924636.47, Temp = 0.01
# Iter 26700: Best cost = 924636.47, Temp = 0.01
# Iter 26800: Best cost = 924636.47, Temp = 0.01
# Iter 26900: Best cost = 924636.47, Temp = 0.01
# Iter 27000: Best cost = 924636.47, Temp = 0.01
# Iter 27100: Best cost = 924636.47, Temp = 0.01
# Iter 27200: Best cost = 924636.47, Temp = 0.01
# Iter 27300: Best cost = 924636.47, Temp = 0.01
# Iter 27400: Best cost = 924636.47, Temp = 0.01
# Iter 27500: Best cost = 924636.47, Temp = 0.01
# Iter 27600: Best cost = 924636.47, Temp = 0.01
# Iter 27700: Best cost = 924636.47, Temp = 0.01
# Iter 27800: Best cost = 924636.47, Temp = 0.01
# Iter 27900: Best cost = 924636.47, Temp = 0.01
# Iter 28000: Best cost = 924636.47, Temp = 0.01
# Iter 28100: Best cost = 924636.47, Temp = 0.01
# Iter 28200: Best cost = 924636.47, Temp = 0.01
# Iter 28300: Best cost = 924636.47, Temp = 0.01
# Iter 28400: Best cost = 924636.47, Temp = 0.01
# Iter 28500: Best cost = 924636.47, Temp = 0.01
# Iter 28600: Best cost = 924636.47, Temp = 0.01
# Iter 28700: Best cost = 924636.47, Temp = 0.01
# Iter 28800: Best cost = 924636.47, Temp = 0.01
# Iter 28900: Best cost = 924636.47, Temp = 0.01
# Iter 29000: Best cost = 924636.47, Temp = 0.01
# Iter 29100: Best cost = 924636.47, Temp = 0.01
# Iter 29200: Best cost = 924636.47, Temp = 0.01
# Iter 29300: Best cost = 924636.47, Temp = 0.01
# Iter 29400: Best cost = 924636.47, Temp = 0.01
# Iter 29500: Best cost = 924636.47, Temp = 0.01
# Iter 29600: Best cost = 924636.47, Temp = 0.01
# Iter 29700: Best cost = 924636.47, Temp = 0.01
# Iter 29800: Best cost = 924636.47, Temp = 0.01
# Iter 29900: Best cost = 924636.47, Temp = 0.01
# Iter 30000: Best cost = 924636.47, Temp = 0.01
# Iter 30100: Best cost = 924636.47, Temp = 0.01
# Iter 30200: Best cost = 924636.47, Temp = 0.01
# Iter 30300: Best cost = 924636.47, Temp = 0.01
# Iter 30400: Best cost = 924636.47, Temp = 0.01
# Iter 30500: Best cost = 924636.47, Temp = 0.01
# Iter 30600: Best cost = 924636.47, Temp = 0.01
# Iter 30700: Best cost = 924636.47, Temp = 0.01
# Iter 30800: Best cost = 924636.47, Temp = 0.01
# Iter 30900: Best cost = 924636.47, Temp = 0.01
# Iter 31000: Best cost = 924636.47, Temp = 0.01
# Iter 31100: Best cost = 924636.47, Temp = 0.01
# Iter 31200: Best cost = 924636.47, Temp = 0.01
# Iter 31300: Best cost = 924636.47, Temp = 0.01
# Iter 31400: Best cost = 924636.47, Temp = 0.01
# Iter 31500: Best cost = 924636.47, Temp = 0.01
# Iter 31600: Best cost = 924636.47, Temp = 0.01
# Iter 31700: Best cost = 924636.47, Temp = 0.01
# Iter 31800: Best cost = 924636.47, Temp = 0.01
# Iter 31900: Best cost = 924636.47, Temp = 0.01
# Iter 32000: Best cost = 924636.47, Temp = 0.01
# Iter 32100: Best cost = 924636.47, Temp = 0.01
# Iter 32200: Best cost = 924636.47, Temp = 0.01
# Iter 32300: Best cost = 924636.47, Temp = 0.01
# Iter 32400: Best cost = 924636.47, Temp = 0.01
# Iter 32500: Best cost = 924636.47, Temp = 0.01
# Iter 32600: Best cost = 924636.47, Temp = 0.01
# Iter 32700: Best cost = 924636.47, Temp = 0.01
# Iter 32800: Best cost = 924636.47, Temp = 0.01
# Iter 32900: Best cost = 924636.47, Temp = 0.01
# Iter 33000: Best cost = 924636.47, Temp = 0.01
# Iter 33100: Best cost = 924636.47, Temp = 0.01
# Iter 33200: Best cost = 924636.47, Temp = 0.01
# Iter 33300: Best cost = 924636.47, Temp = 0.01
# Iter 33400: Best cost = 924636.47, Temp = 0.01
# Iter 33500: Best cost = 924636.47, Temp = 0.01
# Iter 33600: Best cost = 924636.47, Temp = 0.01
# Iter 33700: Best cost = 924636.47, Temp = 0.01
# Iter 33800: Best cost = 924636.47, Temp = 0.01
# Iter 33900: Best cost = 924636.47, Temp = 0.01
# Iter 34000: Best cost = 924636.47, Temp = 0.01
# Iter 34100: Best cost = 924636.47, Temp = 0.01
# Iter 34200: Best cost = 924636.47, Temp = 0.01
# Iter 34300: Best cost = 924636.47, Temp = 0.01
# Iter 34400: Best cost = 924636.47, Temp = 0.01
# Iter 34500: Best cost = 924636.47, Temp = 0.01
# Iter 34600: Best cost = 924636.47, Temp = 0.01
# Iter 34700: Best cost = 924636.47, Temp = 0.01
# Iter 34800: Best cost = 924636.47, Temp = 0.01
# Iter 34900: Best cost = 924636.47, Temp = 0.01
# Iter 35000: Best cost = 924636.47, Temp = 0.01
# Iter 35100: Best cost = 924636.47, Temp = 0.01
# Iter 35200: Best cost = 924636.47, Temp = 0.01
# Iter 35300: Best cost = 924636.47, Temp = 0.01
# Iter 35400: Best cost = 924636.47, Temp = 0.01
# Iter 35500: Best cost = 924636.47, Temp = 0.01
# Iter 35600: Best cost = 924636.47, Temp = 0.01
# Iter 35700: Best cost = 924636.47, Temp = 0.01
# Iter 35800: Best cost = 924636.47, Temp = 0.01
# Iter 35900: Best cost = 924636.47, Temp = 0.01
# Iter 36000: Best cost = 924636.47, Temp = 0.01
# Iter 36100: Best cost = 924636.47, Temp = 0.01
# Iter 36200: Best cost = 924636.47, Temp = 0.01
# Iter 36300: Best cost = 924636.47, Temp = 0.01
# Iter 36400: Best cost = 924636.47, Temp = 0.01
# Iter 36500: Best cost = 924636.47, Temp = 0.01
# Iter 36600: Best cost = 924636.47, Temp = 0.01
# Iter 36700: Best cost = 924636.47, Temp = 0.01
# Iter 36800: Best cost = 924636.47, Temp = 0.01
# Iter 36900: Best cost = 924636.47, Temp = 0.01
# Iter 37000: Best cost = 924636.47, Temp = 0.01
# Iter 37100: Best cost = 924636.47, Temp = 0.01
# Iter 37200: Best cost = 924636.47, Temp = 0.01
# Iter 37300: Best cost = 924636.47, Temp = 0.01
# Iter 37400: Best cost = 924636.47, Temp = 0.01
# Iter 37500: Best cost = 924636.47, Temp = 0.01
# Iter 37600: Best cost = 924636.47, Temp = 0.01
# Iter 37700: Best cost = 924636.47, Temp = 0.01
# Iter 37800: Best cost = 924636.47, Temp = 0.01
# Iter 37900: Best cost = 924636.47, Temp = 0.01
# Iter 38000: Best cost = 924636.47, Temp = 0.01
# Iter 38100: Best cost = 924636.47, Temp = 0.01
# Iter 38200: Best cost = 924636.47, Temp = 0.01
# Iter 38300: Best cost = 924636.47, Temp = 0.01
# Iter 38400: Best cost = 924636.47, Temp = 0.01
# Iter 38500: Best cost = 924636.47, Temp = 0.01
# Iter 38600: Best cost = 924636.47, Temp = 0.01
# Iter 38700: Best cost = 924636.47, Temp = 0.01
# Iter 38800: Best cost = 924636.47, Temp = 0.01
# Iter 38900: Best cost = 924636.47, Temp = 0.01
# Iter 39000: Best cost = 924636.47, Temp = 0.01
# Iter 39100: Best cost = 924636.47, Temp = 0.01
# Iter 39200: Best cost = 924636.47, Temp = 0.01
# Iter 39300: Best cost = 924636.47, Temp = 0.01
# Iter 39400: Best cost = 924636.47, Temp = 0.01
# Iter 39500: Best cost = 924636.47, Temp = 0.01
# Iter 39600: Best cost = 924636.47, Temp = 0.01
# Iter 39700: Best cost = 924636.47, Temp = 0.01
# Iter 39800: Best cost = 924636.47, Temp = 0.01
# Iter 39900: Best cost = 924636.47, Temp = 0.01
# Iter 40000: Best cost = 924636.47, Temp = 0.01
# Iter 40100: Best cost = 924636.47, Temp = 0.01
# Iter 40200: Best cost = 924636.47, Temp = 0.01
# Iter 40300: Best cost = 924636.47, Temp = 0.01
# Iter 40400: Best cost = 924636.47, Temp = 0.01
# Iter 40500: Best cost = 924636.47, Temp = 0.01
# Iter 40600: Best cost = 924636.47, Temp = 0.01
# Iter 40700: Best cost = 924636.47, Temp = 0.01
# Iter 40800: Best cost = 924636.47, Temp = 0.01
# Iter 40900: Best cost = 924636.47, Temp = 0.01
# Iter 41000: Best cost = 924636.47, Temp = 0.01
# Iter 41100: Best cost = 924636.47, Temp = 0.01
# Iter 41200: Best cost = 924636.47, Temp = 0.01
# Iter 41300: Best cost = 924636.47, Temp = 0.01
# Iter 41400: Best cost = 924636.47, Temp = 0.01
# Iter 41500: Best cost = 924636.47, Temp = 0.01
# Iter 41600: Best cost = 924636.47, Temp = 0.01
# Iter 41700: Best cost = 924636.47, Temp = 0.01
# Iter 41800: Best cost = 924636.47, Temp = 0.01
# Iter 41900: Best cost = 924636.47, Temp = 0.01
# Iter 42000: Best cost = 924636.47, Temp = 0.01
# Iter 42100: Best cost = 924636.47, Temp = 0.01
# Iter 42200: Best cost = 924636.47, Temp = 0.01
# Iter 42300: Best cost = 924636.47, Temp = 0.01
# Iter 42400: Best cost = 924636.47, Temp = 0.01
# Iter 42500: Best cost = 924636.47, Temp = 0.01
# Iter 42600: Best cost = 924636.47, Temp = 0.01
# Iter 42700: Best cost = 924636.47, Temp = 0.01
# Iter 42800: Best cost = 924636.47, Temp = 0.01
# Iter 42900: Best cost = 924636.47, Temp = 0.01
# Iter 43000: Best cost = 924636.47, Temp = 0.01
# Iter 43100: Best cost = 924636.47, Temp = 0.01
# Iter 43200: Best cost = 924636.47, Temp = 0.01
# Iter 43300: Best cost = 924636.47, Temp = 0.01
# Iter 43400: Best cost = 924636.47, Temp = 0.01
# Iter 43500: Best cost = 924636.47, Temp = 0.01
# Iter 43600: Best cost = 924636.47, Temp = 0.01
# Iter 43700: Best cost = 924636.47, Temp = 0.01
# Iter 43800: Best cost = 924636.47, Temp = 0.01
# Iter 43900: Best cost = 924636.47, Temp = 0.01
# Iter 44000: Best cost = 924636.47, Temp = 0.01
# Iter 44100: Best cost = 924636.47, Temp = 0.01
# Iter 44200: Best cost = 924636.47, Temp = 0.01
# Iter 44300: Best cost = 924636.47, Temp = 0.01
# Iter 44400: Best cost = 924636.47, Temp = 0.01
# Iter 44500: Best cost = 924636.47, Temp = 0.01
# Iter 44600: Best cost = 924636.47, Temp = 0.01
# Iter 44700: Best cost = 924636.47, Temp = 0.01
# Iter 44800: Best cost = 924636.47, Temp = 0.01
# Iter 44900: Best cost = 924636.47, Temp = 0.01
# Iter 45000: Best cost = 924636.47, Temp = 0.01
# Iter 45100: Best cost = 924636.47, Temp = 0.01
# Iter 45200: Best cost = 924636.47, Temp = 0.01
# Iter 45300: Best cost = 924636.47, Temp = 0.01
# Iter 45400: Best cost = 924636.47, Temp = 0.01
# Iter 45500: Best cost = 924636.47, Temp = 0.01
# Iter 45600: Best cost = 924636.47, Temp = 0.01
# Iter 45700: Best cost = 924636.47, Temp = 0.01
# Iter 45800: Best cost = 924636.47, Temp = 0.01
# Iter 45900: Best cost = 924636.47, Temp = 0.01
# Iter 46000: Best cost = 924636.47, Temp = 0.01
# Iter 46100: Best cost = 924636.47, Temp = 0.01
# Iter 46200: Best cost = 924636.47, Temp = 0.01
# Iter 46300: Best cost = 924636.47, Temp = 0.01
# Iter 46400: Best cost = 924636.47, Temp = 0.01
# Iter 46500: Best cost = 924636.47, Temp = 0.01
# Iter 46600: Best cost = 924636.47, Temp = 0.01
# Iter 46700: Best cost = 924636.47, Temp = 0.01
# Iter 46800: Best cost = 910307.28, Temp = 0.01
# Iter 46900: Best cost = 910307.28, Temp = 0.01
# Iter 47000: Best cost = 910307.28, Temp = 0.01
# Iter 47100: Best cost = 910307.28, Temp = 0.01
# Iter 47200: Best cost = 910307.28, Temp = 0.01
# Iter 47300: Best cost = 910307.28, Temp = 0.01
# Iter 47400: Best cost = 910307.28, Temp = 0.01
# Iter 47500: Best cost = 910307.28, Temp = 0.01
# Iter 47600: Best cost = 910307.28, Temp = 0.01
# Iter 47700: Best cost = 910307.28, Temp = 0.01
# Iter 47800: Best cost = 910307.28, Temp = 0.01
# Iter 47900: Best cost = 910307.28, Temp = 0.01
# Iter 48000: Best cost = 910307.28, Temp = 0.01
# Iter 48100: Best cost = 910307.28, Temp = 0.01
# Iter 48200: Best cost = 909523.92, Temp = 0.01
# Iter 48300: Best cost = 909523.92, Temp = 0.01
# Iter 48400: Best cost = 909523.92, Temp = 0.01
# Iter 48500: Best cost = 909523.92, Temp = 0.01
# Iter 48600: Best cost = 909523.92, Temp = 0.01
# Iter 48700: Best cost = 909523.92, Temp = 0.01
# Iter 48800: Best cost = 909523.92, Temp = 0.01
# Iter 48900: Best cost = 894691.50, Temp = 0.01
# Iter 49000: Best cost = 894691.50, Temp = 0.01
# Iter 49100: Best cost = 894691.50, Temp = 0.01
# Iter 49200: Best cost = 894691.50, Temp = 0.01
# Iter 49300: Best cost = 894691.50, Temp = 0.01
# Iter 49400: Best cost = 894691.50, Temp = 0.01
# Iter 49500: Best cost = 894685.88, Temp = 0.01
# Iter 49600: Best cost = 894685.88, Temp = 0.01
# Iter 49700: Best cost = 894685.88, Temp = 0.01
# Iter 49800: Best cost = 894685.88, Temp = 0.01
# Iter 49900: Best cost = 894685.88, Temp = 0.01
